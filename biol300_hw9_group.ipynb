# %% [markdown]
# <a href="https://colab.research.google.com/github/jaylynnromero/bootcamp/blob/main/biol300_hw9_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem 1 -- Matching the "stories" to the probability distributions (10 points)
#
# For this problem, you may want to revisit the [Probability Distribution Explorer](https://distribution-explorer.github.io/). For each "story" below, state which probability distribution would best describe the scenario and explain why.
#
# A. The time between large (magnitude 8 or higher) earthquakes.
#
# B. The number of bases DNA polymerase can replicate before making an error.
#
# C. The number of errors DNA polymerase make when replicating the entire genome.
#
# D. The chance an instrument in the lab will break a given time we go to use it.
#
# E. The number of steps Mines students take in a day.

# %% [markdown]
# # Problem 2 -- The partitioning of carboxysomes (20 points)
#
# [Carboxysomes](https://en.wikipedia.org/wiki/Carboxysome) are organelle-like structures that some bacteria have to aid in carbon fixation. Cells generally only have a very few number of carboxysomes (1 to 7), so how they are partitioned to the daughter cells is an interesting question. Researchers specifically looked at cells with 6 carboxysomes, and asked how many went to "daughter cell 1" upon cell division, where the daughter cell of interest was randomly selected. They got the following results:
#
# - 15% of the time, the daughter cell got 2 carboxysomes
# - 70% of the time, the daughter cell got 3 carboxysomes
# - 15% of the time, the daughter cell got 4 carboxysomes
#
# Out of 88 trials, no other number of carboxysomes were ever seen.
#
# A. If the carboxysomes were partitioned randomly, which distribution would best describe the number of carboxysomes seen in daughter cell 1?
#
# B. Simulate this random process of seeing how many carboxysomes go to daughter cell 1. First, simulate with "coin flips" for each of the six carboxysomes in turn, recording how many went to the one cell of interest. Simulate this process 10,000 times, and plot the results. Note that a histogram (with 7 bins) would actually be appropriate here, since there are only a handful of discrete possible results, so there is no concern of binning bias.

# %% [markdown]
# C. Now simulate the process again with a built-function from `numpy.random`. Again, plot you results as a way to validate your approach in part B.

# %% [markdown]
# D. Given how the results of your simulations compare to the actual experimental results, do you think the partitioning of carboxysomes is random? Why or why not?

# %% [markdown]
# # Problem 3 -- Simulating the Bicoid gradient (20 points)
#
# [Bicoid](https://en.wikipedia.org/wiki/Bicoid_(gene)) is a key gene in the early development of the fruit fly, *Drosophila*. The protein is initially only found on the anterior (head) side of the embryo and diffuses further down the embryo over time. This ultimately results in a gradient, with diminishing amounts of Bicoid as you go further along the embryo.
#
# In this problem, we will modify the code for a random walk as shown in class on April 6th to simulate this process of the Bicoid gradient getting set up via a diffusive random walk. For this, we will imagine that all the molecules initially start at position `0`, but a key difference will be that molecules cannot take on negative positions. That is, we will treat the left side of the embryo as a boundary that the molecules can not cross. So molecules at position `0` will still have a 50% chance of moving to position `1`, but will otherwise stay at position `0`.
#
# A. Simulate this modified random walk for 1,000 trajectories (i.e. Bicoid molecules), each with 1,000 steps. Plot the distribution of the final positions of the Bicoid molecules.

# %% [markdown]
# B. What distribution does the final position of Bicoid molecules look most like? What is the "story" of this distribution? Does that "story" match what is going on here? Why or why not?

# %% [markdown]
# # Problem 4 -- Variation in binomial partitioning (20 points)
#
# For this problem we will try to recreate what is seen in the following plot:

# %% [markdown]
# ![Screen Shot 2022-04-07 at 12.12.21 PM.png](data:image/png;base64,...)

# %% [markdown]
# For simplicity, we will assign each molecule an intensity of `1`. What we hope to see is that as we increase the total number of fluorescent molecules in the cell, we will get greater variability in the difference between the two daughter cells.
#
# A. Simulate this binomial partitioning for the following number of molecules ($I_{TOT}$): `[5,10,25,50,75,100,150]`. For each, simulate 1,000 trials of the binomial partitioning for the given number of molecules. Note, you will probably prefer to use `numpy`'s built-in function here to make the code more manageable. Save your results as variables you can call in the coming parts.

# %% [markdown]
# B. With the results of the binomial partitioning, now compute the y-axis values $\frac{| I_1-I_2 |}{2}$, which serves as a metric of how much the partitioning varies from perfect partitioning. Note that your results from part A will indicate how many molecules went to one of the cells, say daughter cell 1, but you will have to compute how many went to the other daughter cell as well.

# %% [markdown]
# C. Now get the mean of the results for each possible number of molecules (corresponding to the white dots in the plot). Plot the x-values (number of molecules) against these means. Make sure it looks comparable to the plot above.
